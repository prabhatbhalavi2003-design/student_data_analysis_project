# %%
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/pc/Desktop/student project/data/raw.csv')

# %%
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.tail(10)
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 992   female        group D          associate's degree  free/reduced
# 993   female        group D           bachelor's degree  free/reduced
# 994     male        group A                 high school      standard
# 995   female        group E             master's degree      standard
# 996     male        group C                 high school  free/reduced
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score
# 992                     none          55             76             76
# ...

# %%
df.gender.value_counts()
# Out:
# gender
# female    520
# male      482
# Name: count, dtype: int64

# %%
df.parental_level_of_education.value_counts()
# Out:
# parental_level_of_education
# some college          228
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         math_score  reading_score  writing_score
# count  1002.000000    1002.000000    1002.000000
# mean     66.110778      69.202595      68.089820
# std      15.155758      14.604950      15.201606
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.750000      79.000000
# max     100.000000     100.000000     100.000000

# %%
sns.histplot(data=df, x='math_score', kde=True)
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
df["total_score"] = df["math_score"] + df["reading_score"] + df["writing_score"]

# %%
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
df["average_score"] = df["total_score"] / 3

# %%
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
sns.histplot(data=df, x='total_score', kde=True)
plt.title('avrage score distribution')
plt.xlabel('total score')
plt.ylabel('number of students')    
plt.show()

# %%
df.groupby("gender")["total_score"].mean().reset_index()
# Out:
#    gender  total_score
# 0  female   208.863462
# 1    male   197.512448

# %%
df.groupby("gender")["average_score"].mean().reset_index()
# Out:
#    gender  average_score
# 0  female      69.621154
# 1    male      65.837483

# %%
df.groupby("gender")["total_score"].median().reset_index()
# Out:
#    gender  total_score
# 0  female        211.0
# 1    male        199.0

# %%
plt.hist(df['total_score'], bins=30, edgecolor='black')
plt.title('Distribution of Total Scores')
plt.xlabel('Total Score')
plt.ylabel('Number of Students')
plt.show()

# %%
df.groupby('gender')['total_score'].mean().plot(kind='bar', color=['blue', 'pink'])
plt.title("total_score")
plt.xlabel("gender")
plt.ylabel("total_score")
plt.show()

# %%
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# ...
